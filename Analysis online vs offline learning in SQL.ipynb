# %% [markdown]
# Dataset analysis: https://www.kaggle.com/datasets/prince7489/online-vs-offline-learning-efficiency-dataset

# %%
# %%sql
# SELECT *
# FROM online_vs_offline_learning_dataset
# LIMIT 100;
# Out:
#    Learning_Mode      Subject  Study_Hours  Retention_Score  Focus_Level  \
# 0        Offline      English          7.7               51           96
# 1        Offline      English          6.2               90           82
# 2         Online      English          1.2               75           66
# 3         Online         Math          6.5               80           64
# 4         Online      English          5.5               95           58
# ..           ...          ...          ...              ...          ...
# 95        Online  Programming          5.6               73           54
# 96       Offline         Math          7.5               50           79
# 97        Online      English          6.2               95           79
# 98       Offline         Math          5.1               63           69
# 99        Online      Science          2.2               78           69
#
#     Exam_Score
# 0           70
# 1           81
# 2           71
# 3           77
# 4           78
# ..         ...
# 95          69
# 96          66
# 97          89
# 98          63
# 99          77
#
# [100 rows x 6 columns]
